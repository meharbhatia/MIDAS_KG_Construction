# %%
import spacy
nlp = spacy.load('en')
spacy.__version__
# Out:
# '2.1.0'

# %%
import neuralcoref
coref = neuralcoref.NeuralCoref(nlp.vocab)

# %%
nlp.add_pipe(coref, name='neuralcoref')
# nlp.remove_pipe("neuralcoref")  # This remove the current neuralcoref instance from SpaCy pipe
# coref = neuralcoref.NeuralCoref(nlp.vocab, greedyness=0.75)
# nlp.add_pipe(coref, name='neuralcoref')

# %%
import pandas as pd
# df = pd.read_csv(r'C:\Users\mehar\Desktop\MIDAS\Internship\data\icdm_contest_data.csv')
df = pd.read_csv(r'C:\Users\mehar\Desktop\MIDAS\Internship\data\icdm_contest_data.csv', usecols = ['index', 'content', 'industry'])

# %%
df.head()
# Out:
#    index                                            content  \
# 0      0  Norway has a lot of electric cars—so many that...
# 1      1  Ford says shifter cables can snap off and rend...
# 2      2  Enlarge ImageThe C-Class is still mighty good,...
# 3      3  The 2019 Cadillac CTS-VCNBC | Mack HoganCadill...
# 4      4  featuring 30-inch wheels, a dettatched cabin, ...
#
#                 industry
# 0  automotiveEngineering
# 1  automotiveEngineering
# 2  automotiveEngineering
# 3  automotiveEngineering
# 4  automotiveEngineering

# %%
df_domain_1 = df.loc[(df.industry == 'automotiveEngineering')]

# %%
import nltk
from nltk import tokenize

# %%
final_list  = []
l = len(df)
for i in range(l):
    sent = df['content'].iloc[i]
    final_list.append(tokenize.sent_tokenize(sent))

# %%
longform = pd.DataFrame(columns=['coref_content', 'industry'])
for idx, index, content, industry in df.itertuples():
    content_words = tokenize.sent_tokenize(content)
    
    for nw in content_words:
        doc = nlp(nw)
        doc = doc._.coref_resolved
        longform = longform.append(
            [{'coref_content': doc, 'index':index, 'industry': industry}],
            ignore_index = True
#         longform = longform.append(
#             [{'content': cw} for cw in content_words],
#             ignore_index = True
#         )
    )
    
#     longform = longform.append(
#         [{'content': cw} for cw in content_words],
#         ignore_index = True
#     )

longform['index'] = longform['index'].astype(int)
longform = longform[['index', 'coref_content', 'industry']]
# print(longform['content'].iloc[1])
longform
# Out:
#       index                                      coref_content  \
# 0         0  Norway has a lot of electric cars—so many that...
# 1         0  Mercedes-Benz brought us there to experience t...
# 2         0  Outside Oslo, where cars were larger and more ...
# 3         0  DON'T MISS: Mercedes-Benz EQC Edition 1886 ele...
# 4         0  At about 187 inches long, the EQC400 4Matic cr...
# 5         1  Ford says shifter cables can snap off and rend...
# 6         1  A supplier had added lubricant to these bushin...
# 7         1  Several dangerous things can happen, such as t...
# 8         2  Enlarge ImageThe C-Class is still mighty good,...
# 9         2  Even as gas prices fluctuate, buyers continue ...
# 10        2  It's such a strong push that It might cause at...
# 11        2           Mercedes-Benz declined to comment to AN.
# 12        2  The C-Class came here in 2014, a five-year pro...
# 13        3  The 2019 Cadillac CTS-VCNBC | Mack HoganCadill...
# 14        3  While Cadillac tried to out-German BMW and Mer...
# 15        3  Cadillac, until 2018, offered only one.The 201...
# 16        3  They've announced the XT4 and XT6 crossovers t...
# 17        3  This, the fire-breathing, 200-mile-per-hour CT...
# 18        3  Unfortunately, the market wanted something els...
# 19        4  featuring 30-inch wheels, a dettatched cabin, ...
# 20        4  revealed as part of the company’s centenary ce...
# 21        4  as a result, the cabin, which looks as though ...
# 22        4  developed in collaboration with goodyear, the ...
# 23        4  they are equipped with sensors that monitor ro...
# 24        4  the 19_19 is similar in size to a midsize SUV,...
# 25        5  Mazda is a brand that gives you more than what...
# 26        5  When the 2019 Mazda3 debuted at the 2018 Los A...
# 27        5  From its engaging driving dynamics to its sult...
# 28        5  Move inside and you'll immediately notice Mazd...
# 29        5  Despite its humble underpinnings, the 2019 Maz...
# ...     ...                                                ...
# 1801     64  Although each public safety department has vac...
# 1802     65  “There have been numerous advances in the worl...
# 1803     65  “The NECP has been, in my opinion, one of the ...
# 1804     65  The NECP, coupled with the Public Safety Inter...
# 1805     65  The NECP was responsible for the SWIC (statewi...
# 1806     65  The revised NECP includes a new emergency comm...
# 1807     65  Feedback was collected and incorporated into t...
# 1808     65  The plan is set to be publicly available later...
# 1809     66  Next generation 911 (NG911) holds tremendous p...
# 1810     66  The challenge, however, will be ensuring that ...
# 1811     66  It will ultimately fall upon application devel...
# 1812     67  Drexel University Emergency Medical Services (...
# 1813     67  This team is comprised of Emergency Medical Te...
# 1814     67  Certified by the Pennsylvania Department of He...
# 1815     67  Within the past year, Drexel EMS provided a to...
# 1816     67  Drexel EMS frequently works overnight shifts o...
# 1817     68  President Trump awarded the Medal of Valor to ...
# 1818     68  An elderly woman had been killed and a man lay...
# 1819     68  Two vehicles had collided and a woman in one o...
# 1820     68  The shooter was eventually killed and the offi...
# 1821     69  Macon-Bibb commissioners voted on the 2020 bud...
# 1822     69  It doesn’t include a millage rate increase or ...
# 1823     69  Commissioners said Commissioners promised citi...
# 1824     69  Two commissioners say, the budget didn’t addre...
# 1825     69  “Trying to work out a situation where we can g...
# 1826     69  With no raise in taxes for residents, means no...
# 1827     69  Related Article: Macon-Bibb County Commission ...
# 1828     69  It is an important factor and certainly we’ll ...
# 1829     69  This year, the county is conducting surveys to...
# 1830     69  Mayor Robert Reichert said the surveys will de...
#
#                    industry
# 0     automotiveEngineering
# 1     automotiveEngineering
# 2     automotiveEngineering
# 3     automotiveEngineering
# 4     automotiveEngineering
# 5     automotiveEngineering
# 6     automotiveEngineering
# 7     automotiveEngineering
# 8     automotiveEngineering
# 9     automotiveEngineering
# 10    automotiveEngineering
# 11    automotiveEngineering
# 12    automotiveEngineering
# 13    automotiveEngineering
# 14    automotiveEngineering
# 15    automotiveEngineering
# 16    automotiveEngineering
# 17    automotiveEngineering
# 18    automotiveEngineering
# 19    automotiveEngineering
# 20    automotiveEngineering
# 21    automotiveEngineering
# 22    automotiveEngineering
# 23    automotiveEngineering
# 24    automotiveEngineering
# 25    automotiveEngineering
# 26    automotiveEngineering
# 27    automotiveEngineering
# 28    automotiveEngineering
# 29    automotiveEngineering
# ...                     ...
# 1801         publicSecurity
# 1802         publicSecurity
# 1803         publicSecurity
# 1804         publicSecurity
# 1805         publicSecurity
# 1806         publicSecurity
# 1807         publicSecurity
# 1808         publicSecurity
# 1809         publicSecurity
# 1810         publicSecurity
# 1811         publicSecurity
# 1812         publicSecurity
# 1813         publicSecurity
# 1814         publicSecurity
# 1815         publicSecurity
# 1816         publicSecurity
# 1817         publicSecurity
# 1818         publicSecurity
# 1819         publicSecurity
# 1820         publicSecurity
# 1821         publicSecurity
# 1822         publicSecurity
# 1823         publicSecurity
# 1824         publicSecurity
# 1825         publicSecurity
# 1826         publicSecurity
# 1827         publicSecurity
# 1828         publicSecurity
# 1829         publicSecurity
# 1830         publicSecurity
#
# [1831 rows x 3 columns]

# %%
longform.to_csv("Coref_Dataset.csv", index=False)

# %%
text "Norway has a lot of electric cars—so many that it can make anyone driving a new vehicle with an internal combustion engine look like a Luddite. Mercedes-Benz brought us there to experience the EQC—and possibly to normalize it in a sea of EVs that makes California look like a land of late adopters. Outside Oslo, where cars were larger and more upscale than in other parts of Europe, and Tesla vehicles (S and X) are a more common sight than around Los Angeles or the Bay Area, the EQC fit right in. DON'T MISS: Mercedes-Benz EQC Edition 1886 electric SUV kicks off a new era After a couple of rain-soaked days driving the EQC there last week, we can say that it will be a great addition in the U.S. when it arrives sometime in 2020. At about 187 inches long, the EQC400 4Matic crossover splices into the American mid-sizers."
